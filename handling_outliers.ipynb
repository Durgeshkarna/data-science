# %% [markdown]
# HANDLING OUTLIERS USING PYTHON

# %%
import numpy as np
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
##minimum,q1,median,q3,maximum
minimum,q1,median,q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,q1,median,q3,maximum
# Out:
# (32.0, 54.0, 67.0, 89.0, 99.0)

# %%
iqr=q3-q1

# %%
lower_fence=q1-1.5*(iqr)
higher_fence=q1+1.5*(iqr)

# %%
lower_fence
# Out:
# 1.5

# %%
higher_fence
# Out:
# 106.5

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,1000,1200,1300]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,80]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
